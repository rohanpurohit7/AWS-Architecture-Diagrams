# %% [markdown]
# # Secure VPC Provisioning Lab

# %% [markdown]
# ## Plan
#
# Create a two-AZ VPC with public, private, and isolated subnets.

# %% [markdown]
# ## CIDR Model
#
# Use Python to calculate representative subnet ranges.

# %%
import ipaddress
vpc = ipaddress.ip_network("10.20.0.0/16")
list(vpc.subnets(new_prefix=20))[:6]

# %% [markdown]
# ## Validation
#
# Document route, NACL, security group, NAT, and endpoint checks.

# %% [markdown]
# ## Security Review
#
# Confirm no public database exposure and that logs are enabled.
